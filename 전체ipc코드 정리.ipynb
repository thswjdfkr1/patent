# %%
import pandas as pd
import re

# %%
df3 = pd.read_csv('/content/drive/MyDrive/특허/ipc.csv',encoding='cp949')
print(df3)
# Out:
#       전체 IPC Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       A62C     019/00      [A62C     003/02       A62C     035/02
# 1       H02S     030/20      [B63B     001/32       B63B     025/00
# 2       A61N     005/06      [A61B     034/00       A61B     005/00
# 3       C04B     041/50      [C04B     041/45       C04B     041/48
# 4       G06Q     050/40      [B63H     021/17       G01M     099/00
# ...      ...        ...        ...        ...        ...        ...
# 13825   B60W     030/09      [G08G     001/16       B60T     007/12
# 13826   H04W     024/08      [H04W     036/30       H04W     036/26
# 13827   B65G     001/04      [B65G     057/03       F25D     025/00
# 13828   G06F    003/033      [G06F    003/042       G06F   003/0488
# 13829   H04W     076/15      [H04W     052/14       H04W     052/36
#
#       Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 74  \
# 0           A62C    099/00]        NaN        NaN  ...         NaN
# ...

# %%
df3_clean = df3.apply(lambda x: x.str.replace("[^a-zA-Z0-9]", " ", regex=True))
print(df3_clean)
# Out:
#       전체 IPC Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       A62C     019 00       A62C     003 02       A62C     035 02
# 1       H02S     030 20       B63B     001 32       B63B     025 00
# 2       A61N     005 06       A61B     034 00       A61B     005 00
# 3       C04B     041 50       C04B     041 45       C04B     041 48
# 4       G06Q     050 40       B63H     021 17       G01M     099 00
# ...      ...        ...        ...        ...        ...        ...
# 13825   B60W     030 09       G08G     001 16       B60T     007 12
# 13826   H04W     024 08       H04W     036 30       H04W     036 26
# 13827   B65G     001 04       B65G     057 03       F25D     025 00
# 13828   G06F    003 033       G06F    003 042       G06F   003 0488
# 13829   H04W     076 15       H04W     052 14       H04W     052 36
#
#       Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 74  \
# 0           A62C    099 00         NaN        NaN  ...         NaN
# ...

# %%
df4 = df3_clean.iloc[:,0::2]
df4 = df4.fillna(' ')
df4 = df4.astype(str)
df5 = df4.apply(lambda x: ' '.join(x),axis=1)

# %%
print(df5)
print(df5.shape)
# Out:
# 0        A62C  A62C  A62C  A62C                        ...
# 1        H02S  B63B  B63B  B63H  B63H  B64U  B64U  B64U...
# 2        A61N  A61B  A61B  A61B  C12N                  ...
# 3        C04B  C04B  C04B  C04B  C04B  E04B  C04B  C04B...
# 4        G06Q  B63H  G01M  G06Q  G06Q                  ...
#                                ...
# 13825    B60W  G08G  B60T  B62D  G05D  B60W  B60W  B60W...
# 13826    H04W  H04W  H04W  H04W  H04W                  ...
# 13827    B65G  B65G  F25D  F25C                        ...
# 13828    G06F  G06F  G06F  G06F                        ...
# 13829    H04W  H04W  H04W  H04W  H04W  H04L  H04W  H04W...
# Length: 13830, dtype: object
# (13830,)

# %%
df4.to_csv('zzzz.csv', index=False)
